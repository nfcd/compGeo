# %%
# Import libraries
import numpy as np

# Import function PureShear
import sys, os
sys.path.append(os.path.abspath('../functions'))
from PureShear import PureShear

# Initial points coordinates
pts = np.zeros((16,2))
pts[:,0]=[-1,-1,-1,-1,-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5]
pts[:,1]=[-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5,-1,-1,-1,-1]
st1 = 2.5
ninc = 10

paths,psf = PureShear(pts,st1,ninc)
