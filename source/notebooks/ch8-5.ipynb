# %%
# Import libraries
import numpy as np

# Import function SimpleShear
import sys, os
sys.path.append(os.path.abspath('../functions'))
from SimpleShear import SimpleShear

# Initial points coordinates
pts = np.zeros((16,2))
pts[:,0]=[-1,-1,-1,-1,-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5]
pts[:,1]=[-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5,-1,-1,-1,-1]
gamma = 2.5
ninc = 10
paths,psf = SimpleShear(pts,gamma,ninc)
