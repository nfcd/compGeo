# %%
# Import libraries
import numpy as np

# Import function GeneralShear
import sys, os
sys.path.append(os.path.abspath('../functions'))
from GeneralShear import GeneralShear

# Initial points coordinates
pts = np.zeros((16,2))
pts[:,0]=[-1,-1,-1,-1,-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5]
pts[:,1]=[-1,-0.5,0,0.5,1,1,1,1,1,0.5,0,-0.5,-1,-1,-1,-1]
st1 = 2.0
gamma = 0.5
ninc = 10

# Max. finite stretch parallel to shear direction
kk = 0
paths1,wk1,psf1= GeneralShear(pts,st1,gamma,kk,ninc)
print('Wk = {:.4f}'.format(wk1))
# Out:
# Wk = 0.3393

# %%
# Max. finite stretch perpendicular to shear direction
kk = 1
paths2,wk2,pfs2= GeneralShear(pts,st1,gamma,kk,ninc)
print('Wk = {:.4f}'.format(wk2))
# Out:
# Wk = 0.3393
